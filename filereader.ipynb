# %%
import numpy as np
import numpy.linalg as lin
import os
import matplotlib.pyplot as plt

# %%
path1 = r"C:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\Pictures\scf\'"
dates = ['290725', '300725']
files = [path1 + f'calc{dates[1]}_{i}' for i in range(1,9)]
files.remove(path1 + f'calc{dates[1]}_{3}')
en = '//energies.txt'
nun = '//nus.txt'
deln = '//dels.txt'

# %%
files
# Out:
# ["C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_1",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_2",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_4",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_5",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_6",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_7",
#  "C:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\Pictures\\scf\\'calc300725_8"]

# %%
A=   np.loadtxt(files[0]+en, dtype=float, delimiter=',')
A
# Out:
# array([[-3.05564238, -3.05493104, -3.0527988 , ..., -3.04995288,
#         -3.05421964, -3.05564238],
#        [-3.05564238, -3.05493104, -3.0527988 , ..., -3.04995288,
#         -3.05421964, -3.05564238],
#        [-2.60706002, -2.60634903, -2.60421784, ..., -2.60137238,
#         -2.60563775, -2.60706002],
#        ...,
#        [ 2.60706002,  2.60634903,  2.60421784, ...,  2.60137238,
#          2.60563775,  2.60706002],
#        [ 3.05564238,  3.05493104,  3.0527988 , ...,  3.04995288,
#          3.05421964,  3.05564238],
#        [ 3.05564238,  3.05493104,  3.0527988 , ...,  3.04995288,
#          3.05421964,  3.05564238]])

# %%
np.shape(A)
# Out:
# (12, 300)

# %%
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')

# %%
np.shape(nus[1])
# Out:
# (3, 22)

# %%
fixp = []
nufp = []
infp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
    infp.append(nus[i][:,-1])
fixp=np.array(fixp).T
infp=np.array(infp).T

# %%
mu=[0, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
nus[1][:,-1]
# Out:
# array([0.69067232+0.j, 0.97114856+0.j, 0.69042567+0.j])

# %%
infp[:,-1]
# Out:
# array([1.92490124+0.j, 1.85075574+0.j, 1.92490126+0.j])

# %%
plt.figure(figsize=(8,6))
plt.title('U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$\mu$', size='x-large')
plt.ylabel(r'$\Delta$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, fixp[0], label=r'$\Delta_A$')
plt.plot(mu, fixp[1], label=r'$\Delta_B$')
plt.plot(mu, fixp[2], label=r'$\Delta_C$')

plt.legend(fontsize='x-large')
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\atsch\AppData\Local\Temp\ipykernel_15084\158450626.py:2: SyntaxWarning: invalid escape sequence '\D'
#   plt.title('U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.figure(figsize=(8,6))
plt.title('U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$\mu$', size='x-large')
plt.ylabel(r'$\nu$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, nufp)

plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\atsch\AppData\Local\Temp\ipykernel_15084\1175642325.py:2: SyntaxWarning: invalid escape sequence '\D'
#   plt.title('U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')

# %% [markdown]
# # Variation of U ($\mu=0$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1))

# %%
files = [path1 + f'calc{dates[1]}_{i}' for i in range(9,17)]

# %%
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')

# %%
fixp = []
nufp = []
inufp =[]
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
    inufp.append(nus[i][:,-1])

fixp1=np.array(fixp).T
inufp=np.array(inufp).T

# %%
mu=[0, 0.3, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$U$', size='x-large')
plt.ylabel(r'$\Delta$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, fixp1[0], label=r'$\Delta_A$')
plt.plot(mu, fixp1[1], label=r'$\Delta_B$')
plt.plot(mu, fixp1[2], label=r'$\Delta_C$')

plt.legend(fontsize='x-large')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$U$', size='x-large')
plt.ylabel(r'$\nu$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, nufp)
plt.plot(mu, inufp[0])
plt.plot(mu, inufp[1])
plt.plot(mu, inufp[2])

plt.show()

# %% [markdown]
# # Variation of U ($\mu=0$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(2.8,0.2,-2.8))

# %%
files = [path1 + f'calc{dates[1]}_{i}' for i in range(25,29)]
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')
fixp = []
nufp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
fixp2=np.array(fixp).T
mu2=[0.2, 1, 2, 2.8]

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(2.8,0.2,-2.8)')
plt.xlabel(r'$U$', size='x-large')
plt.ylabel(r'$\Delta$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu2, fixp2[0], label=r'$\Delta_A$')
plt.plot(mu2, fixp2[1], label=r'$\Delta_B$')
plt.plot(mu2, fixp2[2], label=r'$\Delta_C$')

plt.legend(fontsize='x-large')
plt.show()

# %% [markdown]
# # Variation of U ($\mu=0.1$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1))

# %%
files = [path1 + f'calc{dates[1]}_{i}' for i in range(17,25)]
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')
fixp = []
nufp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
fixp=np.array(fixp).T
mu=[0, 0.3, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
plt.figure(figsize=(8,6))
plt.title(r', initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$U$', size='x-large')
plt.ylabel(r'$\Delta$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, fixp[0], label=r'$\mu=0.1$, $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.plot(mu, fixp[1])#, label=r'$\Delta_B$')
plt.plot(mu, fixp[2])#, label=r'$\Delta_C$')
plt.plot(mu, fixp1[0], color= 'blue', linestyle='--', label=r'$\mu=0$, $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.plot(mu, fixp1[1], color= 'blue', linestyle='--')#, label=r'$\mu=0$')
plt.plot(mu, fixp1[2], color= 'blue', linestyle='--')#, label=r'$\mu=0$')
plt.plot(mu2, fixp2[0], color='red', linestyle='dotted', label=r'$\mu=0$, $(\Delta_{A},\Delta_{B},\Delta_{C})$=(2.8,0.2,-2.8)')
plt.plot(mu2, fixp2[1], color='red', linestyle='dotted')#, label=r'$\Delta_B$')
plt.plot(mu2, fixp2[2], color='red', linestyle='dotted')#, label=r'$\Delta_C$')

plt.legend(fontsize='x-large')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0.1$, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(1,0,-1)')
plt.xlabel(r'$U$', size='x-large')
plt.ylabel(r'$\nu$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(mu, nufp)

plt.show()

# %% [markdown]
# # Variation of initial $\Delta_A$ ($\mu=0.5$, U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(x, 0, 0))

# %%
files = [path1 + f'calc{dates[1]}_{i}' for i in range(32,39)]
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')
fixp = []
nufp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
fixp=np.array(fixp).T
da=[0.1, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0.5$, U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(x, 0, 0)')
plt.xlabel(r'initial $\Delta_A$', size='x-large')
plt.ylabel(r'$\Delta$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(da, fixp[0], label=r'$\Delta_A$')
plt.plot(da, fixp[1], label=r'$\Delta_B$')
plt.plot(da, fixp[2], label=r'$\Delta_C$')

plt.legend(fontsize='x-large')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title(r'$\mu=0.5$, U=1, initially $(\Delta_{A},\Delta_{B},\Delta_{C})$=(x, 0, 0)')
plt.xlabel(r'initial $\Delta_A$', size='x-large')
plt.ylabel(r'$\nu$', size='x-large')
plt.xticks(size='x-large')
plt.yticks(size='x-large')

plt.plot(da, nufp)

plt.show()

# %%
files = [path1 + f'calc{dates[1]}_{i}' for i in range(40,41)]
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')
fixp = []
nufp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
fixp=np.array(fixp).T
da=[0.1, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
dels[1][:,-1]
# Out:
# array([-0.0318267 -4.32479943e-19j, -0.09206216-1.24135616e-18j,
#        -0.03176152-4.26425354e-19j])

# %%
nus[1][:,-1]
# Out:
# array([1.82555424+0.j, 1.50493065+0.j, 1.82557008+0.j])

# %%
nufp[-1]
# Out:
# (5.156054966843354+0j)

# %%
files = [path1 + f'calc010825_{i}' for i in range(37,38)]
c=0
energies = {}
dels={}
nus = {}
for file in files:
    c+=1
    energies[c] = np.loadtxt(file+en, dtype=float, delimiter=',')
    dels[c] = np.loadtxt(file+deln, dtype=complex, delimiter=',')
    nus[c] = np.loadtxt(file+nun, dtype=complex, delimiter=',')
fixp = []
nufp = []
for i in dels.keys():
    fixp.append(dels[i][:,-1])
    nufp.append(np.sum(nus[i][:,-1]))
fixp=np.array(fixp).T
da=[0.1, 0.5, 1, 1.5, 2, 2.5, 3]

# %%
fixp
# Out:
# array([[ 0.15510844+1.8753792e-21j],
#        [ 0.        +0.0000000e+00j],
#        [-0.15510844-1.8753792e-21j]])
