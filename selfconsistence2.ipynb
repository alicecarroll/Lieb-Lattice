# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import AHM
reload(AHM)
# Out:
# <module 'AHM' from 'c:\\Users\\atsch\\Desktop\\MasterVorlesungen\\Sommer25\\Lieb-Lattice\\AHM.py'>

# %%
mM = AHM.Model(Del0A = 0, Del0B=0, Del0C= 0, na=1, nb=1, nc=1, mu=5, U=0.2, t=1, inhomp=False, inhomi=True)

H = mM.HBdG()

# %%
k = np.linspace(0, 2*np.pi, 100)

k1 = np.ones(100)
k0 = np.zeros(100)
path = np.concatenate((k, k, k*np.sqrt(2)))
kx = np.concatenate((k,np.pi*2*k1, k[::-1]))
ky = np.concatenate((k0, k, k[::-1]))

p = [i for i in range(np.shape(path)[0])]
np.shape(p)
energies = mM.solvHam(kx, ky)

np.shape(energies)
emax = np.amax(energies)
emax = emax+0.1*emax

# %%
plt.figure(figsize=(8,6))
plt.xlabel("$(k_x a,k_y a)$", size='x-large')
plt.ylabel("E", size='x-large')
plt.yticks(size='x-large')
plt.xticks(ticks= [0, 100, 200, 299], labels=[r"$\Gamma$",r"X",r"M", r"$\Gamma$"], size='x-large')
#plt.ylim((-0.5, 0.5))

for i in energies:
    plt.plot(p, i, color='black')
#for i in energies2:
#    plt.plot(p, i, color='green', linestyle='dashdot')
#plt.plot(p, energies4[0], color='black', label=r'$\Delta_0=0.5$')
#plt.plot(p, energies2[0], color='green', linestyle='dashdot', label=r'$\Delta_0=1$')

plt.vlines([0, 99, 199, 299], [-emax, -emax, -emax, -emax], [emax, emax, emax, emax], colors= 'grey', linestyles='--')
#plt.vlines(250, -2, 2)
#plt.legend(fontsize='x-large')
#plt.savefig("Pictures/ESCpath.png")
plt.show()

# %%
k = np.linspace(0, 2*np.pi, 40)

# %%
mM = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.4, t=0, inhomp=False, inhomi=True)
mM.DeltaN(k)
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:142: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]
# ([(0.19999999999999998-0j), (-0+0j), (-0+0j)], [(1+0j), 0.0, 0.0])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
nus = mM.Deltra(k, N=50)[2]
# Out:
# 0 1
# 1 0.0
# 2 0.7999999996
# 3 0.17739844877976382
# 4 0.03690469469515225
# 5 0.15953402924164292
# 6 0.03397617105722393

# %%
nus2 = mM.Deltra(k, N=50, alpha=0.5)[2]

# %%
nus2
# Out:
# array([[0.        +0.j, 1.        +0.j, 0.5527864 +0.j, 0.68149908+0.j,
#         0.60488931+0.j, 0.68727943+0.j, 0.65979502+0.j, 0.66895724+0.j,
#         0.66590314+0.j, 0.66692118+0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j]])

# %%
s = [np.sum(nus[:,i]) for i in range(np.shape(nus)[1])]

# %%
s2 = [np.sum(nus2[:,i]) for i in range(np.shape(nus2)[1])]

# %%
nus2
# Out:
# array([[0.        +0.j, 1.        +0.j, 0.5527864 +0.j, 0.68149908+0.j,
#         0.60488931+0.j, 0.68727943+0.j, 0.65979502+0.j, 0.66895724+0.j,
#         0.66590314+0.j, 0.66692118+0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j, 0.        +0.j]])

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\nu$')
#plt.ylim(0,0.35)
plt.plot(np.arange(np.shape(nus)[1]), s, label = r'$U=0.2$')
plt.plot(np.arange(np.shape(nus2)[1]), s2, label = r'$U=0.4$')
#plt.plot(np.arange(20), nus[2], label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()
# Out:
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
mM = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.2, t=0, inhomp=False, inhomi=True)
dels = mM.Deltra(k, N=20)[0]

# %%
mM2 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.2, t=0, inhomp=False, inhomi=True)
dels2 = mM2.Deltra(k, N=20)[0]

mM3 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.3, t=0, inhomp=False, inhomi=True)
dels3 = mM3.Deltra(k, N=20)[0]

mM4 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.4, t=0, inhomp=False, inhomi=True)
dels4 = mM4.Deltra(k, N=20)[0]

mM5 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.5, t=0, inhomp=False, inhomi=True)
dels5 = mM5.Deltra(k, N=20)[0]

mM6 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.6, t=0, inhomp=False, inhomi=True)
dels6 = mM6.Deltra(k, N=20)[0]
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:140: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
plt.ylim(0,0.35)
plt.plot(np.arange(20), np.abs(dels[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()

# %%
mM = AHM.Model(Del0A = 1, Del0B=0, Del0C= 1, nA=1, nB=1, nC=1, U=0.2, t=1, inhomp=False, inhomi=True)
dels = mM.Deltra(k, N=20)[0]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
plt.ylim(0,0.35)

plt.plot(np.arange(20), np.abs(dels[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()

# %%
mM = AHM.Model(Del0A = 1, Del0B=0, Del0C= 1, nA=1, nB=1, nC=1, U=0.2, t=1, inhomp=False, inhomi=True)
dels = mM.Deltra(k, N=20)[0]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
plt.ylim(0,0.35)

plt.plot(np.arange(20), np.abs(dels[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()

# %%
mM = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, U=0.2, t=0, inhomp=False, inhomi=True)
vals = mM.Deltra(k, N=20)

mM2 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, nA=0, nB=0, nC=0, U=0.2, t=1, inhomp=False, inhomi=True)
vals2 = mM2.Deltra(k, N=20)

mM3 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, nA=1, nB=1, nC=1, U=0.2, t=1, inhomp=False, inhomi=True)
vals3 = mM3.Deltra(k, N=20)
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:142: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]

# %%
dels = vals[0]
nus = vals[2]
rs = vals[1]

dels2 = vals2[0]
nus2 = vals2[2]
rs2 =vals2[1]

dels3 = vals3[0]
nus3 = vals3[2]
rs3 =vals3[1]

# %%
s1 = [np.sum(nus[:,i]) for i in range(np.shape(nus)[1])]
s2 = [np.sum(nus2[:,i]) for i in range(np.shape(nus2)[1])]
s3 = [np.sum(nus3[:,i]) for i in range(np.shape(nus3)[1])]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\nu$')
#plt.ylim(0,0.35)

plt.plot(np.arange(20), s1, label = r'no hopping')
plt.plot(np.arange(20), s2, label = r't=1, $n_A$=$n_B$=$n_C$=0')
plt.plot(np.arange(20), s3, label = r't=1, $n_A$=$n_B$=$n_C$=1')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()
# Out:
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
#plt.ylim(0,0.35)

plt.plot(np.arange(20), np.abs(dels[0]), label = r'no hopping')
plt.plot(np.arange(20), np.abs(dels2[0]), label = r't=1, $n_A$=$n_B$=$n_C$=0')
plt.plot(np.arange(20), np.abs(dels3[0]), label = r't=1, $n_A$=$n_B$=$n_C$=1')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()

# %%
np.abs(rs3[-5:])
# Out:
# array([0.00211347, 0.00229165, 0.00350889, 0.00221743, 0.00063384])

# %%
(np.abs(rs3[-5:])<0.1).all()
# Out:
# True

# %%
plt.xlabel('Iteration')
plt.ylabel(r'err')
#plt.ylim(0,0.35)

plt.plot(np.arange(20), rs, label = r'no hopping')
plt.plot(np.arange(20), rs2, label = r'no hopping')
plt.plot(np.arange(20), rs3, label = r'no hopping')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r't=1, $n_A$=$n_B$=$n_C$=0')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r't=1, $n_A$=$n_B$=$n_C$=1')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()
# Out:
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Earr = np.linspace(-3,3,100)

# %%
DOS = mM.DOS(Earr, k)
DOS2 = mM2.DOS(Earr, k)
DOS3 = mM3.DOS(Earr, k)
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:270: RuntimeWarning: overflow encountered in square
#   return np.exp(-(E-En)**2/(2*sig**2))
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:270: RuntimeWarning: overflow encountered in divide
#   return np.exp(-(E-En)**2/(2*sig**2))

# %%
plt.xlabel("E", size='x-large')
plt.ylabel("DOS", size='x-large')
plt.yticks(size='x-large')
plt.xticks(size='x-large')
plt.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))
#plt.ylim(0, 1e5)
plt.plot(Earr, DOS, label='t=0; $n_A=n_B=n_C=0$')
plt.plot(Earr, DOS2, label='t=1; $n_A=n_B=n_C=0$')
plt.plot(Earr, DOS3, label='t=1; $n_A=n_B=n_C=1$')
#plt.vlines([emax, -emax], 0, 100, colors='black')
plt.legend()
#plt.savefig("Pictures/DOS_SC.png")
plt.show()

# %%
k = np.linspace(0, 2*np.pi, 40)

# %%
mM = AHM.Model(Del0A = 0.2, Del0B=0, Del0C= -0.2, nA=0.333, nB=0.333, nC=0.333, U=0.1, t=1, inhomp=False, inhomi=True)
dels = mM.Deltra(k, N=20)[0]
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:142: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]

# %%
mM2 = AHM.Model(Del0A = 0.2, Del0B=0, Del0C= -0.2, nA=0.333, nB=0.333, nC=0.333, U=0.5, t=1, inhomp=False, inhomi=True)
dels2 = mM2.Deltra(k, N=20)[0]

# %%
mM3 = AHM.Model(Del0A = 0.2, Del0B=0, Del0C= -0.2, mu=0, muB=0, nA=0.333, nB=0.333, nC=0.333, U=1, t=1, inhomp=False, inhomi=True)
dels3 = mM3.Deltra(k, N=20)[0]

# %%
mM3 = AHM.Model(Del0A = 1, Del0B=0, Del0C= 0, mu=1, muB=0, nA=1, nB=1, nC=1, U=1, t=1, inhomp=True, inhomi=True)
dels3 = mM3.Deltra(k, N=20)[0]
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:140: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
#plt.ylim(0,0.35)

plt.plot(np.arange(50), np.abs(dels[0]), label = r'U=0.1')
plt.plot(np.arange(50), np.abs(dels2[0]), label = r'U=0.5')
plt.plot(np.arange(50), np.abs(dels3[0]), label = r'U=1')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

plt.legend()
plt.show()

# %%
da, db, dc = dels3[:,-1]
na, nb, nc = nus3[:,-1]

# %%
da
# Out:
# (0.20799947851661194-1.5181695648620178e-18j)

# %%
mM = AHM.Model(Del0A = da, Del0B=db, Del0C= dc, nA=na, nB=nb, nC=nc, U=1, t=1, inhomp=False, inhomi=True)

# %%
H = mM.HBdG()

# %%
k = np.linspace(0, 2*np.pi, 100)

k1 = np.ones(100)
k0 = np.zeros(100)
path = np.concatenate((k, k, k*np.sqrt(2)))
kx = np.concatenate((k,np.pi*2*k1, k[::-1]))
ky = np.concatenate((k0, k, k[::-1]))

p = [i for i in range(np.shape(path)[0])]
np.shape(p)
energies = mM.solvHam(kx, ky)

np.shape(energies)
emax = np.amax(energies)
emax = emax+0.1*emax

# %%
plt.figure(figsize=(8,6))
plt.xlabel("$(k_x a,k_y a)$", size='x-large')
plt.ylabel("E", size='x-large')
plt.yticks(size='x-large')
plt.xticks(ticks= [0, 100, 200, 299], labels=[r"$\Gamma$",r"X",r"M", r"$\Gamma$"], size='x-large')
#plt.ylim((-0.5, 0.5))

for i in energies:
    plt.plot(p, i, color='black')
#for i in energies2:
#    plt.plot(p, i, color='green', linestyle='dashdot')
#plt.plot(p, energies4[0], color='black', label=r'$\Delta_0=0.5$')
#plt.plot(p, energies2[0], color='green', linestyle='dashdot', label=r'$\Delta_0=1$')

plt.vlines([0, 99, 199, 299], [-emax, -emax, -emax, -emax], [emax, emax, emax, emax], colors= 'grey', linestyles='--')
#plt.vlines(250, -2, 2)
#plt.legend(fontsize='x-large')
#plt.savefig("Pictures/ESCpath.png")
plt.show()

# %%
Earr = np.linspace(-3.5,3.5,200)
DOS = mM.DOS(Earr, k, sig=0.02)
DOS[0]
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:270: RuntimeWarning: overflow encountered in square
#   return np.exp(-(E-En)**2/(2*sig**2))
# 1.359685759925474e-106

# %%
plt.xlabel("E", size='x-large')
plt.ylabel("DOS", size='x-large')
plt.yticks(size='x-large')
plt.xticks(size='x-large')
plt.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))
#plt.xlim(-0.6, 0.6)
plt.plot(Earr, DOS)

#plt.vlines([emax, -emax], 0, 100, colors='black')
#plt.legend()
#plt.savefig("Pictures/DOS_SC.png")
plt.show()

# %%
da, db, dc = dels2[:,-1]
na, nb, nc = nus2[:,-1]
mM = AHM.Model(Del0A = da, Del0B=db, Del0C= dc, nA=na, nB=nb, nC=nc, U=0.5, t=1, inhomp=False, inhomi=True)
H = mM.HBdG()
k = np.linspace(0, 2*np.pi, 100)

k1 = np.ones(100)
k0 = np.zeros(100)
path = np.concatenate((k, k, k*np.sqrt(2)))
kx = np.concatenate((k,np.pi*2*k1, k[::-1]))
ky = np.concatenate((k0, k, k[::-1]))

p = [i for i in range(np.shape(path)[0])]
np.shape(p)
energies = mM.solvHam(kx, ky)

np.shape(energies)
emax = np.amax(energies)
emax = emax+0.1*emax

# %%
plt.figure(figsize=(8,6))
plt.xlabel("$(k_x a,k_y a)$", size='x-large')
plt.ylabel("E", size='x-large')
plt.yticks(size='x-large')
plt.xticks(ticks= [0, 100, 200, 299], labels=[r"$\Gamma$",r"X",r"M", r"$\Gamma$"], size='x-large')
#plt.ylim((-0.5, 0.5))

for i in energies:
    plt.plot(p, i, color='black')
#for i in energies2:
#    plt.plot(p, i, color='green', linestyle='dashdot')
#plt.plot(p, energies4[0], color='black', label=r'$\Delta_0=0.5$')
#plt.plot(p, energies2[0], color='green', linestyle='dashdot', label=r'$\Delta_0=1$')

plt.vlines([0, 99, 199, 299], [-emax, -emax, -emax, -emax], [emax, emax, emax, emax], colors= 'grey', linestyles='--')
#plt.vlines(250, -2, 2)
#plt.legend(fontsize='x-large')
#plt.savefig("Pictures/ESCpath.png")
plt.show()

# %%
da, db, dc = dels[:,-1]
na, nb, nc = nus[:,-1]
mM = AHM.Model(Del0A = da, Del0B=db, Del0C= dc, nA=na, nB=nb, nC=nc, U=0.1, t=1, inhomp=False, inhomi=True)
H = mM.HBdG()
k = np.linspace(0, 2*np.pi, 100)

k1 = np.ones(100)
k0 = np.zeros(100)
path = np.concatenate((k, k, k*np.sqrt(2)))
kx = np.concatenate((k,np.pi*2*k1, k[::-1]))
ky = np.concatenate((k0, k, k[::-1]))

p = [i for i in range(np.shape(path)[0])]
np.shape(p)
energies = mM.solvHam(kx, ky)

np.shape(energies)
emax = np.amax(energies)
emax = emax+0.1*emax

# %%
plt.figure(figsize=(8,6))
plt.xlabel("$(k_x a,k_y a)$", size='x-large')
plt.ylabel("E", size='x-large')
plt.yticks(size='x-large')
plt.xticks(ticks= [0, 100, 200, 299], labels=[r"$\Gamma$",r"X",r"M", r"$\Gamma$"], size='x-large')
#plt.ylim((-0.5, 0.5))

for i in energies:
    plt.plot(p, i, color='black')
#for i in energies2:
#    plt.plot(p, i, color='green', linestyle='dashdot')
#plt.plot(p, energies4[0], color='black', label=r'$\Delta_0=0.5$')
#plt.plot(p, energies2[0], color='green', linestyle='dashdot', label=r'$\Delta_0=1$')

plt.vlines([0, 99, 199, 299], [-emax, -emax, -emax, -emax], [emax, emax, emax, emax], colors= 'grey', linestyles='--')
#plt.vlines(250, -2, 2)
#plt.legend(fontsize='x-large')
#plt.savefig("Pictures/ESCpath.png")
plt.show()

# %%
mM = AHM.Model(Del0A = 0, Del0B=0, Del0C= 0, nA=1, nB=1, nC=1, mu=-7, muB=-9, U=0.2, t=1, inhomp=True, inhomi=True)
vals = mM.Deltra(k, N=20)
# Out:
# c:\Users\atsch\Desktop\MasterVorlesungen\Sommer25\Lieb-Lattice\AHM.py:142: ComplexWarning: Casting complex values to real discards the imaginary part
#   sortedEVals[sum(degen):sum(degen)+d]=inbet[t]

# %%
dels = vals[0]
nus = vals[2]
s=[np.sum(nus[:,i]) for i in range(np.shape(nus)[1])]

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\nu$')
#plt.ylim(0,0.35)
plt.plot(np.arange(20), s, label = r'$U=0.2$')
#plt.plot(np.arange(20), s2, label = r'$U=0.4$')
#plt.plot(np.arange(20), nus[2], label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

#plt.legend()
plt.show()

# %%
plt.xlabel('Iteration')
plt.ylabel(r'$\Delta$')
#plt.ylim(0,0.35)
plt.plot(np.arange(20), dels[0], label = r'$U=0.2$')
plt.plot(np.arange(20), dels[1], label = r'$U=0.2$')
plt.plot(np.arange(20), dels[2], label = r'$U=0.2$')
#plt.plot(np.arange(20), s2, label = r'$U=0.4$')
#plt.plot(np.arange(20), nus[2], label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels2[0]), label = r'$U=0.2$')
#plt.plot(np.arange(20), np.abs(dels3[0]), label = r'$U=0.3$')
#plt.plot(np.arange(20), np.abs(dels4[0]), label = r'$U=0.4$')
#plt.plot(np.arange(20), np.abs(dels5[0]), label = r'$U=0.5$')
#plt.plot(np.arange(20), np.abs(dels6[0]), label = r'$U=0.6$')

#plt.plot(np.arange(20), dels3[0], label = r'$\Delta_C$')

#plt.legend()
plt.show()
# Out:
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\atsch\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
da, db, dc = dels[:,-1]
na, nb, nc = nus[:,-1]
mM = AHM.Model(Del0A = da, Del0B=db, Del0C= dc, nA=na, nB=nb, nC=nc, mu=-7, muB=-9, U=0.2, t=1, inhomp=True, inhomi=True)
H = mM.HBdG()
k = np.linspace(0, 2*np.pi, 100)

k1 = np.ones(100)
k0 = np.zeros(100)
path = np.concatenate((k, k, k*np.sqrt(2)))
kx = np.concatenate((k,np.pi*2*k1, k[::-1]))
ky = np.concatenate((k0, k, k[::-1]))

p = [i for i in range(np.shape(path)[0])]
np.shape(p)
energies = mM.solvHam(kx, ky)

np.shape(energies)
emax = np.amax(energies)
emax = emax+0.1*emax

# %%
plt.figure(figsize=(8,6))
plt.xlabel("$(k_x a,k_y a)$", size='x-large')
plt.ylabel("E", size='x-large')
plt.yticks(size='x-large')
plt.xticks(ticks= [0, 100, 200, 299], labels=[r"$\Gamma$",r"X",r"M", r"$\Gamma$"], size='x-large')
#plt.ylim((-0.5, 0.5))

for i in energies:
    plt.plot(p, i, color='black')
#for i in energies2:
#    plt.plot(p, i, color='green', linestyle='dashdot')
#plt.plot(p, energies4[0], color='black', label=r'$\Delta_0=0.5$')
#plt.plot(p, energies2[0], color='green', linestyle='dashdot', label=r'$\Delta_0=1$')
#plt.hlines(1, 0, 300, colors='blue')
plt.vlines([0, 99, 199, 299], [-emax, -emax, -emax, -emax], [emax, emax, emax, emax], colors= 'grey', linestyles='--')
#plt.vlines(250, -2, 2)
#plt.legend(fontsize='x-large')
#plt.savefig("Pictures/ESCpath.png")
plt.show()
